# %%
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/us-accidents/US_Accidents_March23.csv")

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (7728394, 46)

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat                  0
# End_Lng                  0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Temperature(F)           0
# Wind_Chill(F)            0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# Traffic_Calming          0
# Traffic_Signal           0
# Turning_Loop             0
# Sunrise_Sunset           0
# Civil_Twilight           0
# Nautical_Twilight        0
# Astronomical_Twilight    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3554549 entries, 3402762 to 7728393
# Data columns (total 48 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Source                 object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Street                 object
#  11  City                   object
#  12  County                 object
#  13  State                  object
#  14  Zipcode                object
#  15  Country                object
#  16  Timezone               object
#  17  Airport_Code           object
#  18  Weather_Timestamp      object
#  19  Temperature(F)         float64
#  20  Wind_Chill(F)          float64
#  21  Humidity(%)            float64
#  22  Pressure(in)           float64
#  23  Visibility(mi)         float64
#  24  Wind_Direction         object
#  25  Wind_Speed(mph)        float64
#  26  Precipitation(in)      float64
#  27  Weather_Condition      object
#  28  Amenity                bool
#  29  Bump                   bool
#  30  Crossing               bool
#  31  Give_Way               bool
#  32  Junction               bool
#  33  No_Exit                bool
#  34  Railway                bool
#  35  Roundabout             bool
#  36  Station                bool
#  37  Stop                   bool
#  38  Traffic_Calming        bool
#  39  Traffic_Signal         bool
#  40  Turning_Loop           bool
#  41  Sunrise_Sunset         object
#  42  Civil_Twilight         object
#  43  Nautical_Twilight      object
#  44  Astronomical_Twilight  object
#  45  start_day              int32
#  46  start_hr               object
#  47  start_date             object
# dtypes: bool(13), datetime64[ns](1), float64(12), int32(1), int64(1), object(20)
# memory usage: 1006.8+ MB

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df["Weather_Timestamp"].value_counts()
# Out:
# Weather_Timestamp
# 2022-03-13 01:53:00    1116
# 2021-01-26 15:53:00     619
# 2022-05-13 16:53:00     525
# 2022-05-17 15:53:00     475
# 2022-04-29 14:53:00     463
#                        ...
# 2016-02-09 07:48:00       1
# 2016-02-09 07:58:00       1
# 2016-02-09 07:53:00       1
# 2016-02-09 11:12:00       1
# 2016-02-09 12:53:00       1
# Name: count, Length: 440189, dtype: int64

# %%
sns.countplot(y="Weather_Timestamp",data=df[: 30])
plt.show()

# %%
df["City"].value_counts()
# Out:
# City
# Miami             142575
# Los Angeles        79444
# Orlando            74911
# Dallas             50074
# Houston            46197
#                    ...
# Hahnville              1
# Plaistow               1
# Olympia Fields         1
# Jeanerette             1
# South Paris            1
# Name: count, Length: 10327, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(y="City",data=df[: 30],palette="Set1")
plt.show()

# %%
df.head()
# Out:
#                 ID   Source  Severity           Start_Time  \
# 3402762  A-3412645  Source1         3  2016-02-08 00:37:08
# 3402767  A-3412650  Source1         3  2016-02-08 07:53:43
# 3402771  A-3412654  Source1         2  2016-02-08 11:51:46
# 3402773  A-3412656  Source1         2  2016-02-08 15:16:43
# 3402774  A-3412657  Source1         2  2016-02-08 15:43:50
#
#                     End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  \
# 3402762  2016-02-08 06:37:08  40.108910 -83.092860  40.112060 -83.031870
# 3402767  2016-02-08 13:53:43  39.172393 -84.492792  39.170476 -84.501798
# 3402771  2016-02-08 17:51:46  41.375310 -81.820170  41.367860 -81.821740
# 3402773  2016-02-08 21:16:43  40.109310 -82.968490  40.110780 -82.984000
# 3402774  2016-02-08 21:43:50  39.192880 -84.477230  39.196150 -84.473350
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 3402762         3.230  ...      False   False  False           False
# 3402767         0.500  ...      False   False  False           False
# 3402771         0.521  ...      False   False  False           False
# 3402773         0.826  ...      False   False  False           False
# 3402774         0.307  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 3402762          False        False          Night          Night
# 3402767          False        False            Day            Day
# 3402771          False        False            Day            Day
# 3402773          False        False            Day            Day
# 3402774          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 3402762             Night                 Night
# 3402767               Day                   Day
# 3402771               Day                   Day
# 3402773               Day                   Day
# 3402774               Day                   Day
#
# [5 rows x 46 columns]

# %%
df.Start_Time=pd.to_datetime(df.Start_Time,format='mixed')
df.Start_Time
# Out:
# 3402762   2016-02-08 00:37:08
# 3402767   2016-02-08 07:53:43
# 3402771   2016-02-08 11:51:46
# 3402773   2016-02-08 15:16:43
# 3402774   2016-02-08 15:43:50
#                   ...
# 7728389   2019-08-23 18:03:25
# 7728390   2019-08-23 19:11:30
# 7728391   2019-08-23 19:00:21
# 7728392   2019-08-23 19:00:21
# 7728393   2019-08-23 18:52:06
# Name: Start_Time, Length: 3554549, dtype: datetime64[ns]

# %%
df['start_day']=df.Start_Time.dt.day
df['start_day']
# Out:
# 3402762     8
# 3402767     8
# 3402771     8
# 3402773     8
# 3402774     8
#            ..
# 7728389    23
# 7728390    23
# 7728391    23
# 7728392    23
# 7728393    23
# Name: start_day, Length: 3554549, dtype: int32

# %%
df['start_hr']=df.Start_Time.dt.time
df.start_hr
# Out:
# 3402762    00:37:08
# 3402767    07:53:43
# 3402771    11:51:46
# 3402773    15:16:43
# 3402774    15:43:50
#              ...
# 7728389    18:03:25
# 7728390    19:11:30
# 7728391    19:00:21
# 7728392    19:00:21
# 7728393    18:52:06
# Name: start_hr, Length: 3554549, dtype: object

# %%
time_of_accident=df.start_hr.value_counts()
time_of_accident
# Out:
# start_hr
# 15:45:00    1961
# 15:50:00    1909
# 15:51:00    1907
# 15:41:00    1899
# 14:47:00    1897
#             ...
# 01:05:02       1
# 02:13:36       1
# 04:40:26       1
# 03:14:08       1
# 05:47:43       1
# Name: count, Length: 86231, dtype: int64

# %%
time_of_accident_high=time_of_accident[time_of_accident>=1000]
time_of_accident_low=time_of_accident[time_of_accident<1000]

print(time_of_accident_high,'\n',time_of_accident_low)
# Out:
# start_hr
# 15:45:00    1961
# 15:50:00    1909
# 15:51:00    1907
# 15:41:00    1899
# 14:47:00    1897
#             ...
# 10:07:00    1001
# 10:10:00    1001
# 21:12:00    1000
# 20:52:00    1000
# 11:29:00    1000
# Name: count, Length: 794, dtype: int64
#  start_hr
# 20:09:00    999
# 10:33:00    999
# 11:15:00    999
# 19:49:00    998
# 10:44:00    998
#            ...
# 01:05:02      1
# 02:13:36      1
# 04:40:26      1
# 03:14:08      1
# 05:47:43      1
# Name: count, Length: 85437, dtype: int64

# %%
time_of_accident_high[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='start_hr'>

# %% [markdown]
# # day 22 records for the highest number of accidents and day 311 the least

# %%
df.start_day.value_counts()
# Out:
# start_day
# 23    136337
# 22    132665
# 16    126847
# 14    124243
# 18    124202
# 19    123635
# 15    123591
# 21    122362
# 17    122132
# 13    121727
# 12    121630
# 11    121384
# 20    120924
# 1     117595
# 24    116692
# 10    113504
# 4     113036
# 3     111995
# 2     111317
# 27    111244
# 9     110693
# 5     108665
# 8     108283
# 28    107910
# 6     107625
# 30    107485
# 7     107110
# 26    106285
# 25    105531
# 29    102927
# 31     64973
# Name: count, dtype: int64

# %%
df['start_date']=df.Start_Time.dt.date

# %%
df['start_date']
# Out:
# 3402762    2016-02-08
# 3402767    2016-02-08
# 3402771    2016-02-08
# 3402773    2016-02-08
# 3402774    2016-02-08
#               ...
# 7728389    2019-08-23
# 7728390    2019-08-23
# 7728391    2019-08-23
# 7728392    2019-08-23
# 7728393    2019-08-23
# Name: start_date, Length: 3554549, dtype: object

# %%
df.start_date.value_counts()
# Out:
# start_date
# 2022-12-23    9332
# 2022-12-22    8822
# 2022-12-15    8642
# 2023-01-25    8580
# 2023-01-27    8504
#               ...
# 2017-07-09       1
# 2019-08-24       1
# 2016-03-20       1
# 2018-07-29       1
# 2017-10-29       1
# Name: count, Length: 2431, dtype: int64

# %% [markdown]
# # max acidents occured on 2022-12-23 10067

# %%
df.Start_Time.dt.month.value_counts()
# Out:
# Start_Time
# 12    478254
# 1     396539
# 11    370563
# 2     319368
# 10    287306
# 9     281952
# 4     277005
# 6     254581
# 5     253036
# 3     229137
# 8     212778
# 7     194030
# Name: count, dtype: int64

# %%
df["Severity"].value_counts()
# Out:
# Severity
# 2    3348445
# 4     112511
# 3      68026
# 1      25567
# Name: count, dtype: int64

# %%
sns.countplot(x="Severity",data=df)
plt.show()

# %%
df.drop(columns="ID",axis=1,inplace=True)

# %%
df["Source"].value_counts()
# Out:
# Source
# Source1    3554549
# Name: count, dtype: int64

# %%
sns.histplot(data=df["Start_Lat"][: 200], kde=True)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df["Start_Lng"][: 200], kde=True,color="navy")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df["End_Lat"][: 200], kde=True,color="brown")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df["End_Lng"][: 200], kde=True,color="orange")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df["Distance(mi)"][: 200], kde=True,color="green")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["Country"].value_counts()
# Out:
# Country
# US    3554549
# Name: count, dtype: int64

# %%
sns.countplot(y="Country",data=df[: 30])
# Out:
# <Axes: xlabel='count', ylabel='Country'>

# %%
df["State"].value_counts()
# Out:
# State
# CA    880453
# FL    529393
# TX    178750
# VA    176331
# NY    168004
# PA    161697
# SC    136485
# NC    132011
# OR    125802
# MN    116608
# TN     74679
# AZ     73067
# NJ     72341
# LA     68749
# MD     66544
# MI     55275
# GA     53580
# UT     45625
# IL     42194
# CT     41343
# CO     36258
# OH     32050
# MO     32006
# WA     31598
# AL     26786
# MT     26293
# IN     23553
# AR     18629
# DC     13544
# IA     11920
# WI     11703
# KS     11551
# OK     11294
# WV     11160
# ID      8884
# NV      7762
# MS      6990
# DE      6596
# MA      5267
# KY      4685
# NE      3406
# RI      2817
# ND      2705
# NM      2495
# WY      2421
# NH      1840
# ME       989
# VT       220
# SD       196
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.countplot(y="State",data=df)
plt.show()

# %%
df["Weather_Condition"].value_counts()
# Out:
# Weather_Condition
# Fair                                   1697787
# Cloudy                                  524654
# Mostly Cloudy                           457519
# Partly Cloudy                           311743
# Light Rain                              164310
#                                         ...
# Blowing Snow Nearby                          1
# Light Thunderstorms and Snow                 1
# Heavy Ice Pellets                            1
# Light Rain Shower / Windy                    1
# Heavy Thunderstorms with Small Hail          1
# Name: count, Length: 122, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.countplot(y="Weather_Condition",data=df)
plt.show()

# %%
sns.histplot(data=df["Humidity(%)"], kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Humidity(%)', ylabel='Count'>

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, _)) = plt.subplots(2, 3, figsize=(18, 12))
colors = ['#ff9999', '#66b3ff']
explode = (0.2, 0,)  

val1 = len(df[df['Station'] == True])
val2 = len(df[df['Station'] == False])
ax1.set_title('Station')
ax1.pie([val1, val2], labels=[True, False], autopct='%1.1f%%', explode=explode, shadow=True, colors=colors)

val1 = len(df[df['Stop'] == True])
val2 = len(df[df['Stop'] == False])
ax2.set_title('Stop')
ax2.pie([val1, val2], labels=[True, False], autopct='%1.1f%%', explode=explode, shadow=True, colors=colors)

val1 = len(df[df['Traffic_Calming'] == True])
val2 = len(df[df['Traffic_Calming'] == False])
ax3.set_title('Traffic_Calming')
ax3.pie([val1, val2], labels=[True, False], autopct='%1.1f%%', explode=explode, shadow=True, colors=colors)

val1 = len(df[df['Traffic_Signal'] == True])
val2 = len(df[df['Traffic_Signal'] == False])
ax4.set_title('Traffic_Signal')
ax4.pie([val1, val2], labels=[True, False], autopct='%1.1f%%', explode=explode, shadow=True, colors=colors)

val1 = len(df[df['Sunrise_Sunset'] == 'Night'])
val2 = len(df[df['Sunrise_Sunset'] == 'Day'])
ax5.set_title('Sunrise_Sunset')
ax5.pie([val1, val2], labels=['Night', 'Day'], autopct='%1.1f%%', explode=explode, shadow=True, colors=colors);
fig.delaxes(_)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hypothesis

# %%
alpha = 0.05
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Sunrise_Sunset'], df['Severity'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print('p-value:', p)
print("The following null hypothesis is", p > alpha, ": There is no statistically significant relationship between the Day/Night and accident severity.")
# Out:
# p-value: 0.0
# The following null hypothesis is False : There is no statistically significant relationship between the Day/Night and accident severity.

# %%
from scipy import stats

morning_severity = df[(df.Start_Time.dt.hour >= 0) & (df.Start_Time.dt.hour < 6)]['Severity']
afternoon_severity = df[(df.Start_Time.dt.hour >= 6) & (df.Start_Time.dt.hour < 12)]['Severity']
evening_severity = df[(df.Start_Time.dt.hour >= 12) & (df.Start_Time.dt.hour < 18)]['Severity']
night_severity = df[(df.Start_Time.dt.hour >= 18)]['Severity']

f_statistic, p = stats.f_oneway(morning_severity, afternoon_severity, evening_severity, night_severity)

alpha = 0.05
print('p-value:', p)
print("The following null hypothesis is", p > alpha, ": There is no statistically significant difference in the severity of accidents across different times of day.")
# Out:
# p-value: 0.0
# The following null hypothesis is False : There is no statistically significant difference in the severity of accidents across different times of day.

# %%
feature_categories = df['Weather_Condition'].unique()
data = []
for category in feature_categories:
    data.append(df[df['Weather_Condition'] == category]['Severity'])
_, p = stats.f_oneway(*data)


print('p-value:', p)
print("The following null hypothesis is", p > alpha, ": There is no statistically significant difference in the severity of accidents across different weather conditions.")
# Out:
# p-value: 0.0
# The following null hypothesis is False : There is no statistically significant difference in the severity of accidents across different weather conditions.

# %%
df['Severity'] = pd.to_numeric(df['Severity'], errors='coerce')

hot_weather = df[df['Temperature(F)'] > 90]['Severity']
cold_weather = df[df['Temperature(F)'] < 32]['Severity']

t_stat, p = stats.ttest_ind(hot_weather, cold_weather, equal_var=False)

alpha = 0.05
print('p-value:', p)
print("The following null hypothesis is", p > alpha, ": There is no significant difference in accident severity between hot and cold weather.")
# Out:
# p-value: 0.0
# The following null hypothesis is False : There is no significant difference in accident severity between hot and cold weather.
